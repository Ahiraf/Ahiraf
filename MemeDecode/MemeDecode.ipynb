# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahiraf/Ahiraf/blob/main/MemeDecode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-310f20a6-2cea-4a17-8bfa-72d58f6a4305" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-310f20a6-2cea-4a17-8bfa-72d58f6a4305">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

zip_path = "MemeDecode.zip"
extract_path = "Meme/"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
import pandas as pd

train_df = pd.read_csv("/content/Meme/MemeDecode/Train/Train.csv")
train_df.head()
# Out:
#            Image_name    Target  Unnamed: 2
# 0      Political1.jpg  Politics         NaN
# 1      Political2.jpg  Politics         NaN
# 2       Gendered1.jpg   Genders         NaN
# 3       Gendered2.jpg   Genders         NaN
# 4  NonAggressive1.jpg   Neutral         NaN

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Corrected: Assume images are in an 'Image' subfolder within the Train directory
img_path = "/content/Meme/MemeDecode/Train/Image/" + train_df.iloc[0]["Image_name"]
img = Image.open(img_path)

plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1439.5), np.float64(990.5), np.float64(-0.5))
